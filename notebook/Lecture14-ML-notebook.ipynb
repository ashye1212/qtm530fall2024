# %% [markdown]
# 1022 Regression Tree
# - Decision Tree [better to communicate with normal audience ]
#   - Version I - Basic
#   - Version II
#     - When the tree is too deep -> overfit; low bias, high variance
#     - When the tree is too shallow -> High bias, low variance
#   - Version III Random Forest -
#     - Taking a subset of variables at random
#
# 1024 Cross-validation
# - prediction algorithms
#   1) risk/loss function : L(data, theta, lambda)
#      1) theta --> model parameter
#      2) lambda -> tuning parameters
#   2) obtaining optimal model estimates given tuning parameter
#   3) optimize the tuning parameter in an another batch of data
# - example
#   - observations
#   - randomly split the data
#   -
#
# - cross-fitting
#   - split dataset info
#   - loss_matrix
#   - loss_vec_tuning
#
# - tradeoff
#   - k-fold with k< n

# %% [markdown]
# ![prediction algorithms](attachment:image.png)
